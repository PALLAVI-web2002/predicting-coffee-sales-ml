# %% [markdown]
# <a href="https://colab.research.google.com/github/PALLAVI-web2002/predicting-coffee-sales-ml/blob/main/how_to_study_the_large_datasets_and_plot_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
file_path = '/real_estate_db.csv'
df = pd.read_csv(file_path, encoding='latin1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39030 entries, 0 to 39029
# Data columns (total 80 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   UID                          39030 non-null  int64
#  1   BLOCKID                      0 non-null      float64
#  2   SUMLEVEL                     39030 non-null  int64
#  3   COUNTYID                     39030 non-null  int64
#  4   STATEID                      39030 non-null  int64
#  5   state                        39030 non-null  object
#  6   state_ab                     39030 non-null  object
#  7   city                         39030 non-null  object
#  8   place                        39030 non-null  object
#  9   type                         39030 non-null  object
#  10  primary                      39030 non-null  object
#  11  zip_code                     39030 non-null  int64
#  12  area_code                    39030 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# UID                0
# BLOCKID        39030
# SUMLEVEL           0
# COUNTYID           0
# STATEID            0
#                ...
# pct_own          390
# married          275
# married_snp      275
# separated        275
# divorced         275
# Length: 80, dtype: int64

# %%
df['pop'].mean()
# Out:
# np.float64(4331.384678452472)

# %%
df['pop'].median()
# Out:
# 4065.0

# %%
df['pop'].hist()
# Out:
# <Axes: >

# %%
df['pop'].std()
# Out:
# 2155.2023884361756

# %%
import seaborn as sns

# %%
df['state'].value_counts()
# Out:
# state
# California              4193
# Texas                   2767
# New York                2565
# Florida                 2289
# Pennsylvania            1735
# Illinois                1593
# Ohio                    1538
# Michigan                1463
# North Carolina          1167
# Georgia                 1078
# New Jersey              1009
# Virginia                1006
# Washington               806
# Indiana                  802
# Arizona                  798
# Tennessee                792
# Massachusetts            777
# Maryland                 764
# Wisconsin                732
# Missouri                 732
# Minnesota                699
# Colorado                 668
# Alabama                  612
# Louisiana                608
# Kentucky                 577
# South Carolina           561
# Oklahoma                 552
# Puerto Rico              489
# Oregon                   454
# Connecticut              445
# Kansas                   440
# Iowa                     415
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                   UID  BLOCKID  SUMLEVEL  COUNTYID   STATEID  zip_code  \
# UID          1.000000      NaN       NaN  0.262793  0.976741 -0.226358
# BLOCKID           NaN      NaN       NaN       NaN       NaN       NaN
# SUMLEVEL          NaN      NaN       NaN       NaN       NaN       NaN
# COUNTYID     0.262793      NaN       NaN  1.000000  0.224276  0.034973
# STATEID      0.976741      NaN       NaN  0.224276  1.000000 -0.265258
# ...               ...      ...       ...       ...       ...       ...
# pct_own      0.070306      NaN       NaN -0.001070  0.068407 -0.067898
# married      0.040333      NaN       NaN -0.015853  0.024639  0.031060
# married_snp -0.038978      NaN       NaN  0.035130 -0.033785  0.015877
# separated    0.017849      NaN       NaN  0.064160  0.029272 -0.052255
# divorced     0.011845      NaN       NaN  0.048415  0.017777  0.046124
#
#              area_code       lat       lng     ALand  ...  female_age_mean  \
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >
